# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset/Global_terrorist.csv', encoding='ISO-8859-1')
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
filtered_df = df[df['region_txt'] == 'Middle East & North Africa']

# Filter by year 
filtered_df = filtered_df[filtered_df['iyear'] >= 2000]

# Filter by attack type 
filtered_df = filtered_df[filtered_df['attacktype1_txt'] == 'Bombing/Explosion']

# Filter by significant impact 
filtered_df = filtered_df[filtered_df['nkill'] >= 10]

print(f"Filtered dataset size: {len(filtered_df)} rows")
# Out:
# Filtered dataset size: 1737 rows

# %%
import folium
from folium.plugins import HeatMap

# Aggregate incidents by latitude and longitude
aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')

print(aggregated_df.head())
# Out:
#     latitude  longitude  incident_count
# 0  12.743795  44.843678               1
# 1  12.760069  44.890266               1
# 2  12.825647  44.846416              12
# 3  12.832581  45.027071               1
# 4  12.867085  44.981911               6

# %% [markdown]
# <h1> GEOSPATIAL WITH FOLIUM LIBRARY </h1>

# %%
filtered_df = df[(df['region_txt'] == 'Middle East & North Africa') & (df['iyear'] >= 2000)]

# Aggregate incidents by location
aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')

# # Normalize weights (optional)
aggregated_df['normalized_weight'] = (aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) / \
                                (aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min())

# Prepare heat_data
heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()

# Create a base map
m = folium.Map(location=[30, 40], zoom_start=4)

# Add heatmap layer
HeatMap(heat_data).add_to(m)

# Save or display the map
m.save('terrorism_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
aggregated_df
# Out:
#        latitude  longitude  incident_count  normalized_weight
# 0     12.533136  47.922339               1                0.0
# 1     12.640356  44.118781               1                0.0
# 2     12.683549  43.458797               1                0.0
# 3     12.714722  44.207778               1                0.0
# 4     12.725161  43.494482               1                0.0
# ...         ...        ...             ...                ...
# 7667  41.226460  28.648640               1                0.0
# 7668  41.252757  42.354672               1                0.0
# 7669  41.292758  36.331211               1                0.0
# 7670  41.378494  33.776276               1                0.0
# 7671  41.410610  33.700055               1                0.0
#
# [7672 rows x 4 columns]

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# <h1>CASUALTY ANALYSIS</h1>

# %% [markdown]
# <h3>This illustrates the locations of terrorist incidents in South Asia from the year 2000 onward, where at least 10 individuals were injured</h3>

# %% [markdown]
# <h3></h3>

# %%
casualty_region = df[(df['iyear'] >= 2000)]
casualty_region = casualty_region[(casualty_region['region_txt'] == 'South Asia') & (casualty_region['nwound'] >= 10)]

aggregated_df = casualty_region.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
aggregated_df['normalized_weight'] = (aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) / \
                                (aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min())

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
m = folium.Map(location=[30, 40], zoom_start=4)
HeatMap(heat_data).add_to(m)
m.save('terrorism_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>TARGET ANALYSIS</h1>

# %% [markdown]
# <h3>The analysis reveals that the main targets of terrorist attacks in Egypt and Libya during this time were military checkpoints and military personnel, especially in incidents with 15 or more fatalities. This is shown in the heatmap, which displays where these attacks occurred. These targeting patterns are influenced by the unrest following the Arab Spring and ongoing political instability. They show how terrorists aim to disrupt everyday life, weaken military power, and challenge the authority of the state.</h3>

# %%
target_filtered = df[(df['iyear'] >= 2014) & (df['region_txt'] == 'South Asia')]
target_filtered = target_filtered[(target_filtered['targtype1_txt'] == 'Private Citizens & Property')]
aggregated_df = target_filtered.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')

aggregated_df['normalized_weight'] = (aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) / \
                                (aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min())

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
m = folium.Map(location=[30, 40], zoom_start=4)
HeatMap(heat_data).add_to(m)
m.save('terrorism_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>DEMOGRAPHIC ANALYSIS</h1>

# %% [markdown]
# <h3>This shows where terrorists have attacked police officers in South America since the year 2000. These attacks mainly focus on law enforcement, showing a plan to weaken the government and create fear in the public. The data highlights the places and number of attacks on police security forces, which are often connected to crime and political problems. This shows the tough challenges police face in keeping people safe and maintaining order in their communities.</h3>

# %%
target_filtered = df[(df['iyear'] >= 2000) & (df['region_txt'] == 'South America')]
target_filtered = target_filtered[(target_filtered['targsubtype1_txt'] == 'Police Security Forces/Officers')]
aggregated_df = target_filtered.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')


aggregated_df['normalized_weight'] = (aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) / \
                                (aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min())

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
m = folium.Map(location=[30, 40], zoom_start=4)
HeatMap(heat_data).add_to(m)
m.save('terrorism_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>CRIME TYPE ANALYSIS</h1>

# %% [markdown]
# <h3>This analysis shows that bombings are concentrated in busy city areas and that there are many different types of attacks from 1970 to now, especially those that result in more than the average number of deaths (2.40).It also reveals that bombing and explosion incidents are a major type of attack in the Middle East and North Africa since 2000, especially in countries like Algeria, Yemen, Israel, the West Bank and Gaza Strip, Iraq, Syria, Egypt, Libya, Lebanon, and Jordan. These countries face bombings because of their unique conflicts and the specific goals of terrorist groups.</h3>

# %%
print('earliest year recorded: ' + f'{df['iyear'].min()},' + ' kill mean: ' + f'{df['nkill'].mean()}')
filtered_df = df[df['region_txt'] == 'Middle East & North Africa']
filtered_df = filtered_df[filtered_df['iyear'] >= 2000]
filtered_df = filtered_df[filtered_df['nkill'] >= 10]
bombing_df = filtered_df[filtered_df['attacktype1_txt'] == 'Bombing/Explosion']
affected_countries = bombing_df['country_txt'].unique()
affected_countries
# Out:
# earliest year recorded: 1970, kill mean: 2.4032722986614385
# array(['Algeria', 'Yemen', 'Israel', 'West Bank and Gaza Strip',
#        'Tunisia', 'Saudi Arabia', 'Morocco', 'Iraq', 'Turkey', 'Egypt',
#        'Lebanon', 'Jordan', 'Iran', 'Syria', 'Libya', 'Kuwait'],
#       dtype=object)

# %%
aggregated_df = filtered_df_top_attack.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')

aggregated_df['normalized_weight'] = (aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) / \
                                    (aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min())

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
m = folium.Map(location=[30, 40], zoom_start=4)
HeatMap(heat_data).add_to(m)
m.save('attack_type_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>REGIONAL ANALYSIS</h1>

# %% [markdown]
# <h3>Since 1990, Southeast Asia has seen many bombing and explosion incidents, especially those that resulted in 10 or more deaths. These attacks are linked to local problems, extremist.</h3>

# %%
regional = df[df['region_txt'] == 'Southeast Asia']
regional = regional[regional['iyear'] >= 1990]
regional = regional[regional['attacktype1_txt'] == 'Bombing/Explosion']
regional = regional[regional['nkill'] >= 10]

print(f"Filtered dataset size: {len(regional)} rows")

aggre_reg = regional.groupby(['latitude', 'longitude']).size().reset_index(name='Incident Count')
aggre_reg['normalized_weight'] = (aggre_reg['Incident Count'] - aggre_reg['Incident Count'].min()) / \
                                 (aggre_reg['Incident Count'].max() - aggre_reg['Incident Count'].min())

heat_data_reg = aggre_reg[['latitude', 'longitude', 'normalized_weight']].values.tolist()

map_reg = folium.Map(location=[5, 120], zoom_start=5)
HeatMap(heat_data_reg).add_to(map_reg)
map_reg.save('regional_heatmap.html')
map_reg
# Out:
# Filtered dataset size: 44 rows
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>ATTACKS PER YEAR</h1>

# %% [markdown]
# <h3>The data on terrorist attacks from 1970 to 2017 shows that the number of attacks increased a lot over the years. The highest number of attacks happened in 2014, with 16,903 incidents. There were big increases in attacks in the early 2000s, especially after the September 11 attacks in 2001. In the late 1990s, the number of attacks dropped to 934 in 1998. The 2010s had many attacks, staying above 10,000 from 2012 to 2014. Overall, the data shows that terrorism in the region is a serious and ongoing problem, affected by world events, and it is important to keep watching and responding to it.</h3>

# %%
attacks = df["iyear"].value_counts(dropna=False).sort_index().to_frame().reset_index()
attacks.columns = ["iyear", "Attacks"]
attacks.set_index("iyear", inplace=True)
print(attacks)
# Out:
#        Attacks
# iyear
# 1970       651
# 1971       471
# 1972       568
# 1973       473
# 1974       581
# 1975       740
# 1976       923
# 1977      1319
# 1978      1526
# 1979      2662
# 1980      2662
# 1981      2586
# 1982      2544
# 1983      2870
# 1984      3495
# 1985      2915
# 1986      2860
# 1987      3183
# 1988      3721
# 1989      4324
# 1990      3887
# 1991      4683
# 1992      5071
# 1994      3456
# 1995      3081
# 1996      3058
# 1997      3197
# 1998       934
# 1999      1395
# 2000      1814
# 2001      1906
# 2002      1333
# 2003      1278
# 2004      1166
# 2005      2017
# 2006      2758
# 2007      3242
# 2008      4805
# 2009      4721
# 2010      4826
# 2011      5076
# 2012      8522
# 2013     12036
# 2014     16903
# 2015     14965
# 2016     13587
# 2017     10900
