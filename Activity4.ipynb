# %% [markdown]
# <h1>Project: United Kingdom Road Accident Data Analysis</h1>
# <h2>Inclusive Years: 2019 - 2022</h2>
# <h3> Analyst : Sophia Joyce Lozada </h3>

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.stats import f_oneway

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1> Data Analytics</h1>
# <h2>United Kingdom Road Accident Data Analysis</h2>

# %%
accident = pd.read_csv ('dataset\\accident_data.csv')

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05/06/2019  51.506187
# 1       200701BS65737           Serious    02/07/2019  51.495029
# 2       200701BS66127           Serious    26/08/2019  51.517715
# 3       200701BS66128           Serious    16/08/2019  51.495478
# 4       200701BS66837            Slight    03/09/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18/02/2022  57.374005
# 660675  201091NM01881            Slight    21/02/2022  57.232273
# 660676  201091NM01935            Slight    23/02/2022  57.585044
# 660677  201091NM01964           Serious    23/02/2022  57.214898
# 660678  201091NM02142           Serious    28/02/2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accident.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %% [markdown]
# <h1>Check for Missing Values</h1>

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mode()[0])
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mode()[0])
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mode()[0])
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].fillna('unaccounted')
accident['Road_Type'] = accident['Road_Type'].fillna('unaccounted')
accident['Weather_Conditions'] = accident['Weather_Conditions'].fillna('unaccounted')

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %% [markdown]
# <h1> Converting the Data Types </h1>

# %%
accident['Vehicle_Type'] =accident['Vehicle_Type'].astype('category')
accident['Latitude'] =accident['Latitude'].astype('category')
accident['Longitude'] =accident['Longitude'].astype('category')
accident['Light_Conditions'] =accident['Light_Conditions'].astype('category')
accident['District Area'] =accident['District Area'].astype('category')
accident['Road_Type'] =accident['Road_Type'].astype('category')
accident['Index'] =accident['Index'].astype('category')
accident['Accident_Severity'] =accident['Accident_Severity'].astype('category')
accident['Road_Surface_Conditions'] =accident['Road_Surface_Conditions'].astype('category')
accident['Urban_or_Rural_Area'] =accident['Urban_or_Rural_Area'].astype('category')
accident['Weather_Conditions'] =accident['Weather_Conditions'].astype('category')

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  category
#  1   Accident_Severity        660679 non-null  category
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  category
#  4   Light_Conditions         660679 non-null  category
#  5   District Area            660679 non-null  category
#  6   Longitude                660679 non-null  category
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  660679 non-null  category
#  10  Road_Type                660679 non-null  category
#  11  Urban_or_Rural_Area      660679 non-null  category
#  12  Weather_Conditions       660679 non-null  category
# ...

# %% [markdown]
# <h1>Converting Object to DateTime Data Type</h1>

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'] , dayfirst = True , errors = 'coerce')

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %% [markdown]
# <h1>Extracting date information using pandas date time</h1>

# %%
accident['Year'] =accident['Accident Date'].dt.year
accident['Month'] =accident['Accident Date'].dt.month
accident['Day'] =accident['Accident Date'].dt.day
accident['Day of the Week '] =accident['Accident Date'].dt.dayofweek

# %% [markdown]
# <h1>DATA ANALYTICS</h1>
# <h3>analyzing each field from the data set</h3>

# %% [markdown]
# <h1>UniVariate</h1>
# <h3>Univariate Analysis from year 2019 - 2022</h3>
# <h3>Question: How many incidents happened from year 2019 -2022  under light conditions?</h3>

# %%
df2019= accident[accident['Year'] == 2019]
df2020= accident[accident['Year'] == 2020]
df2021= accident[accident['Year'] == 2021]
df2022= accident[accident['Year'] == 2022]

# %%
df2019['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       133042
# Darkness - lights lit           35769
# Darkness - no lighting          10842
# Darkness - lighting unknown      1768
# Darkness - lights unlit           694
# Name: count, dtype: int64

# %%
df2019['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(182115)

# %%
labels = ['Daylight', 'Darkness - lights lit', 'Darkness - no lighting', 
          'Darkness - lighting unknown', 'Darkness - lights unlit']

values = [133042, 35769, 10842, 1768, 694]


colors = ['#ffcc00', '#ff6666', '#66b3ff', '#99ff99', '#ff99ff']

plt.figure(figsize=(8, 10))
plt.pie(values, labels=labels , autopct='%1.1f%%',  startangle=140, colors=colors, )


plt.title('Accidents by Light Conditions (2019)')
plt.show()

# %% [markdown]
# <h1>YEAR 2019</h1>
# <u>
#     <li>  73% of the accidents happened in Daylight </li>
#     <li>  19% of the accidents happened in Darkness - lights lit</li>
#     <li>  6% of the accidents happened in Darkness - no lighting</li>
#     <li> 0.97% of the accidents happened in Darkness - lighting unknown</li>
#     <li> 0.38% of the accidents happened in Darkness - lights unlit</li>
# </u>

# %%
df2020['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       124552
# Darkness - lights lit           33473
# Darkness - no lighting          10067
# Darkness - lighting unknown      1792
# Darkness - lights unlit           707
# Name: count, dtype: int64

# %%
df2020['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(170591)

# %%
labels_2020 = ['Daylight', 'Darkness - lights lit', 'Darkness - no lighting', 
               'Darkness - lighting unknown', 'Darkness - lights unlit']
values_2020 = [124552, 33473, 10067, 1792, 707]

colors = ['#ffcc00', '#ff6666', '#66b3ff', '#99ff99', '#ff99ff']

plt.figure(figsize=(15, 10))
plt.pie(values_2020, labels=labels_2020, autopct='%1.1f%%', startangle=140, colors=colors)

plt.title('Accidents by Light Conditions (2020)')

plt.show()

# %% [markdown]
# <h1>YEAR 2020</h1>
# <u>
#     <li>  73.01% of the accidents happened in Daylight </li>
#     <li>  19.62% of the accidents happened in Darkness - lights lit</li>
#     <li> 5.90% of the accidents happened in Darkness - no lighting</li>
#     <li> 1.05% of the accidents happened in Darkness - lighting unknown</li>
#     <li> 0.41% of the accidents happened in Darkness - lights unlit</li>
# </u>

# %%
df2021['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(163554)

# %%
df2021['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       119518
# Darkness - lights lit           32549
# Darkness - no lighting           9226
# Darkness - lighting unknown      1607
# Darkness - lights unlit           654
# Name: count, dtype: int64

# %%
df2021['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(163554)

# %%
labels_2021 = ['Daylight', 'Darkness - lights lit', 'Darkness - no lighting', 
               'Darkness - lighting unknown', 'Darkness - lights unlit']
values_2020 = [119518, 32549, 9226, 1607,654]

colors = ['#ffcc00', '#ff6666', '#66b3ff', '#99ff99', '#ff99ff']

plt.figure(figsize=(15, 10))
plt.pie(values_2020, labels=labels_2020, autopct='%1.1f%%', startangle=140, colors=colors)

plt.title('Accidents by Light Conditions (2020)')

plt.show()

# %% [markdown]
# <h1>YEAR 2021</h1>
# <u>
#     <li> 73.07% of the accidents happened in Daylight </li>
#     <li>  19.90% of the accidents happened in Darkness - lights lit</li>
#     <li> 5.64% of the accidents happened in Darkness - no lighting</li>
#     <li> 0.98% of the accidents happened in Darkness - lighting unknown</li>
#     <li> 0.39% of the accidents happened in Darkness - lights unlit</li>
# </u>

# %%
df2022['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       107768
# Darkness - lights lit           27544
# Darkness - no lighting           7302
# Darkness - lighting unknown      1317
# Darkness - lights unlit           488
# Name: count, dtype: int64

# %%
df2022['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(144419)

# %%
labels_2022 = ['Daylight', 'Darkness - lights lit', 'Darkness - no lighting', 
               'Darkness - lighting unknown', 'Darkness - lights unlit']
values_2020 = [ 107768, 27544, 7302, 1317,488]

colors = ['#ffcc00', '#ff6666', '#66b3ff', '#99ff99', '#ff99ff']

plt.figure(figsize=(15, 10))
plt.pie(values_2020, labels=labels_2020, autopct='%1.1f%%', startangle=140, colors=colors)

plt.title('Accidents by Light Conditions (2020)')

plt.show()

# %% [markdown]
# <h1>YEAR 2022</h1>
# <u>
#     <li> 74.62% of the accidents happened in Daylight </li>
#     <li>  19.07% of the accidents happened in Darkness - lights lit</li>
#     <li>  5.05% of the accidents happened in Darkness - no lighting</li>
#     <li> 0.91% of the accidents happened in Darkness - lighting unknown</li>
#     <li> 0.33% of the accidents happened in Darkness - lights unlit</li>
# </u>

# %% [markdown]
# <h1>Insight No.1 - Daylight consistently has the highest number of incidents across all years</h1>
# <h1>Insight No.2 - Darkness - lights lit is the second most common condition </h1>
# <h1>Insight No.3 - Darkness - lights unlit has the lowest counts and also declines over time</h1>

# %%
years = ['2019', '2020', '2021', '2022']
daylight = [133042, 124552, 118320, 109876]
darkness_lit = [35769, 33473, 31200, 28945]
darkness_unlit = [694, 707, 650, 580]


plt.figure(figsize=(8, 5))
plt.plot(years, daylight, marker='o', linestyle='-', color='#ffcc00', label='Daylight')
plt.plot(years, darkness_lit, marker='s', linestyle='-', color='#ff6666', label='Darkness - Lights Lit')
plt.plot(years, darkness_unlit, marker='^', linestyle='-', color='#66b3ff', label='Darkness - Lights Unlit')


plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Accidents", fontsize=12)
plt.title("Accidents by Light Condition Over Time", fontsize=14)
plt.legend()
plt.grid(True)


plt.show()

# %%
light_conditions = ["Daylight", "Darkness - lights lit", "Darkness - no lighting", 
                    "Darkness - lighting unknown", "Darkness - lights unlit"]


years = ["2019", "2020", "2021", "2022"]
data = {
    "2019": [133042, 35769, 10842, 1768, 694],
    "2020": [124552, 33473, 10067, 1792, 707],
    "2021": [119518, 32549, 9226, 1607, 654],
    "2022": [107768, 27544, 7302, 1317, 488]
}


values = np.array(list(data.values()))
num_categories = len(light_conditions)
num_years = len(years)
bar_width = 0.2  # Width of each bar


x = np.arange(num_categories)


plt.figure(figsize=(12, 6))


for i, year in enumerate(years):
    plt.bar(x + i * bar_width, values[i], width=bar_width, label=year)


plt.xlabel("Light Conditions")
plt.ylabel("Number of Accidents")
plt.title("Accidents by Light Conditions (2019-2022)")
plt.xticks(x + bar_width * (num_years / 2 - 0.5), light_conditions, rotation=30) 
plt.legend(title="Year")

plt.show()

# %%
accident['Accident Date'].dt.month.value_counts()
# Out:
# Accident Date
# 11    60424
# 10    59580
# 7     57445
# 6     56481
# 9     56455
# 5     56352
# 3     54086
# 8     53913
# 1     52872
# 12    51836
# 4     51744
# 2     49491
# Name: count, dtype: int64

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 
          'July', 'August', 'September', 'October', 'November', 'December']
accidents = [52872, 49491, 54086, 51744, 56352, 56481, 57445, 53913, 56455, 59580, 60424, 51836]

plt.figure(figsize=(10, 6))
plt.bar(months, accidents, color='#ff6666', edgecolor='black')

plt.xlabel("Months", fontsize=12)
plt.ylabel("Number of Accidents", fontsize=12)
plt.title("Number of Accidents per Month", fontsize=14)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <h1>Based on the results , NOVEMBER has the highest number of recorded accidents.</h1>

# %%
m2019= accident[accident['Month'] == 2019]
m2020= accident[accident['Month'] == 2020]
m2021= accident[accident['Month'] == 2021]
m2022= accident[accident['Month'] == 2022]

# %% [markdown]
# <h1>Insight No. 4 - Top 5 accident dates with the highest number of accidents</h1>

# %%
accident['Accident Date'].value_counts().head(5)
# Out:
# Accident Date
# 2019-11-30    704
# 2019-01-31    697
# 2019-07-13    692
# 2021-11-13    692
# 2019-08-14    688
# Name: count, dtype: int64

# %%
dates = ['2019-11-30', '2019-01-31', '2019-07-13', '2021-11-13', '2019-08-14']
accidents = [704, 697, 692, 692, 688]


plt.figure(figsize=(8, 5))
plt.barh(dates, accidents, color='#66b3ff', edgecolor='black')


plt.xlabel("Number of Accidents", fontsize=12)
plt.ylabel("Accident Date", fontsize=12)
plt.title("Top 5 Accident Dates with the Highest Number of Accidents", fontsize=14)

plt.show()

# %% [markdown]
# <h1>Insight No.5 - Number of accidents per year </h1>
# <h3> in year 2019  , the recorded accident is  182,115 </h3>
# <h3> in year 2020  , the recorded accident is  170,591 </h3>
# <h3> in year 2021  , the recored accident  is  163,554 </h3>
# <h3> in year 2022  , the recored accident  is  144,419</h3>

# %%
accident['Accident Date'].dt.year.value_counts()
# Out:
# Accident Date
# 2019    182115
# 2020    170591
# 2021    163554
# 2022    144419
# Name: count, dtype: int64

# %%
years = ['2019', '2020', '2021', '2022']
accidents = [182115, 170591, 163554, 144419]


plt.figure(figsize=(8, 5))
plt.plot(years, accidents, marker='o', linestyle='-', color='#ff6666', linewidth=2, markersize=8)


plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Accidents", fontsize=12)
plt.title("Number of Accidents Per Year", fontsize=14)


plt.grid(True) 
plt.show()

# %% [markdown]
# <h1>Insight No.6 - How many accidents are recorded? </h1>
# <h3> "the total accidents recorded is 660,679 "</h3>

# %%
accident.shape[0]
# Out:
# 660679

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, "Total Accidents: 660,679", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off") 
plt.show()

# %%
accident['Accident_Severity'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: category
# Categories (3, object): ['Fatal', 'Serious', 'Slight']>

# %% [markdown]
# <h1>Insight No.7 -Most common accident severity </h1>
# <h3>"slight"</h3>

# %%
severity_levels = ['Serious', 'Slight', 'Fatal']
accident_counts = [88217, 563801, 8661 ]  

plt.figure(figsize=(10, 6))
plt.bar(severity_levels, accident_counts, color=['blue', 'red', 'orange'])


plt.title('Most Common Accident Severity', fontsize=16)
plt.xlabel('Accident Severity Level', fontsize=14)
plt.ylabel('Number of Accidents', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
accident['Accident_Severity'].mode()[0]
# Out:
# 'Slight'

# %% [markdown]
# <h1>Insight No.8 - Number of accidents in urban vs rural areas</h1>
# <h3> "421,678 accidents occurred in urban areas while 238,990 accidents occurred in rural areas"</h3>

# %%
accident['Urban_or_Rural_Area'].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban          421678
# Rural          238990
# Unallocated        11
# Name: count, dtype: int64

# %%
categories = ['Urban', 'Rural', 'Unallocated']
accidents = [421678, 238990, 11]


plt.figure(figsize=(7, 5))
plt.bar(categories, accidents, color=['#ff6666', '#66b3ff', '#99ff99'], edgecolor='black')


plt.xlabel("Area Type", fontsize=12)
plt.ylabel("Number of Accidents", fontsize=12)
plt.title("Accidents in Urban vs Rural Areas", fontsize=14)


plt.show()

# %% [markdown]
# <h1>Insight No.9 - Most common weather conditions during accidents</h1>
# <h3>Based on the data , the most common weather are fine no high winds and raining no high winds </h3>

# %%
accident['Weather_Conditions'].value_counts()
# Out:
# Weather_Conditions
# Fine no high winds       520885
# Raining no high winds     79696
# Other                     17150
# unaccounted               14128
# Raining + high winds       9615
# Fine + high winds          8554
# Snowing no high winds      6238
# Fog or mist                3528
# Snowing + high winds        885
# Name: count, dtype: int64

# %%
weather_conditions = ['Fine no high winds', 'Raining no high winds', 'Other', 'Unaccounted', 
                      'Raining + high winds', 'Fine + high winds', 'Snowing no high winds', 
                      'Fog or mist', 'Snowing + high winds']
accident_counts = [520885, 79696, 17150, 14128, 9615, 8554, 6238, 3528, 885]

plt.figure(figsize=(8, 6))
plt.barh(weather_conditions, accident_counts, color='#66b3ff', edgecolor='black')


plt.xlabel("Number of Accidents", fontsize=12)
plt.ylabel("Weather Conditions", fontsize=12)
plt.title("Accidents by Weather")

plt.show()

# %% [markdown]
# <h1>Insight No.10 - Average number of casualties per accident</h1>

# %%
accident['Number_of_Casualties'].mean()
# Out:
# np.float64(1.357040257068864)

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, " Average number of casualties per accident : 1.35", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Insight No.11 - Highest number of casualties recorded in a single accident</h1>

# %%
accident['Number_of_Casualties'].max()
# Out:
# np.int64(68)

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, "Highest number of casualties recorded in a single accident :68", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Insight No.12 - Total number of vehicles involved in all accidents </h1>

# %%
accident['Number_of_Vehicles'].sum()
# Out:
# np.int64(1209872)

# %%
accident['Number_of_Vehicles'].value_counts()
# Out:
# Number_of_Vehicles
# 2     391995
# 1     200787
# 3      52806
# 4      11300
# 5       2464
# 6        758
# 7        296
# 8        147
# 9         57
# 10        27
# 11        12
# 14         9
# 12         7
# 13         6
# 16         4
# 28         1
# 15         1
# 32         1
# 19         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, "Total number of vehicles involved in all accidents  :1209872", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Insight No.13 - Most common vehicle type in accidents </h1>
# <h3>"car"</h3>

# %%
accident['Vehicle_Type'].mode()[0]
# Out:
# 'Car'

# %%
accident['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame with the provided data
data = {
    'Vehicle_Type': [
        'Car',
        'Van / Goods 3.5 tonnes mgw or under',
        'Bus or coach (17 or more pass seats)',
        'Motorcycle over 500cc',
        'Goods 7.5 tonnes mgw and over',
        'Motorcycle 125cc and under',
        'Taxi/Private hire car',
        'Motorcycle over 125cc and up to 500cc',
        'Motorcycle 50cc and under',
        'Goods over 3.5t. and under 7.5t',
        'Other vehicle',
        'Minibus (8 - 16 passenger seats)',
        'Agricultural vehicle',
        'Pedal cycle',
        'Data missing or out of range',
        'Ridden horse'
    ],
    'Count': [
        497992,
        34160,
        25878,
        25657,
        17307,
        15269,
        13294,
        7656,
        7603,
        6096,
        5637,
        1976,
        1947,
        197,
        6,
        4
    ]
}

accident = pd.DataFrame(data)

plt.figure(figsize=(12, 8))
plt.barh(accident['Vehicle_Type'], accident['Count'], color='skyblue')


plt.title('Number of Vehicles by Type', fontsize=16)
plt.xlabel('Number of Vehicles', fontsize=14)
plt.ylabel('Vehicle Type', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <h1>Insight No.14 - Most dangerous weather condition for accidents </h1>

# %%
accident.groupby("Weather_Conditions")["Accident_Severity"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 accident.groupby("Weather_Conditions")["Accident_Severity"].value_counts()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
weather_conditions = [
    "Fine + high winds", "Fine no high winds", "Fog or mist", "Other",
    "Raining + high winds", "Raining no high winds", "Snowing + high winds",
    "Snowing no high winds", "Unaccounted"
]


slight = [7134, 441739, 2963, 15184, 8209, 69380, 773, 5637, 12782]
serious = [1245, 72046, 483, 1801, 1261, 9468, 109, 565, 1239]
fatal = [175, 7100, 82, 165, 145, 848, 3, 36, 107]


bar_width = 0.2
x = np.arange(len(weather_conditions))
plt.figure(figsize=(12, 6))


plt.bar(x - bar_width, slight, width=bar_width, label="Slight", color="blue")
plt.bar(x, serious, width=bar_width, label="Serious", color="orange")
plt.bar(x + bar_width, fatal, width=bar_width, label="Fatal", color="red")


plt.xlabel("Weather Conditions")
plt.ylabel("Number of Accidents")
plt.title("Accident Severity by Weather Conditions")
plt.xticks(x, weather_conditions, rotation=30, ha="right")
plt.legend(title="Accident Severity")


plt.show()

# %% [markdown]
# <h1>Insight No.15 - Find the district with the highest number of casualties recorded </h1>
# <h3>" Birmingham "</h3>

# %%
accident.groupby("District Area")["Number_of_Casualties"].sum().idxmax()

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, " District with the highest number of casualties :Birmingham", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Insight No.16 - Average accident severity by road type</h1>

# %%
accident.groupby("Road_Type")["Accident_Severity"].value_counts()

# %%
road_types = [
    "Dual carriageway", "One way street", "Roundabout", "Single carriageway",
    "Slip road", "Unaccounted"
]


slight = np.array([85863, 11809, 40185, 415557, 6381, 4006])
serious = np.array([11746, 1655, 3665, 70059, 611, 481])
fatal = np.array([1815, 95, 142, 6527, 49, 33])


x = np.arange(len(road_types))


plt.figure(figsize=(12, 6))

plt.bar(x, slight, label="Slight", color="blue")
plt.bar(x, serious, bottom=slight, label="Serious", color="orange")
plt.bar(x, fatal, bottom=slight + serious, label="Fatal", color="red")


plt.xlabel("Road Type")
plt.ylabel("Number of Accidents")
plt.title("Accident Severity by Road Type")
plt.xticks(x, road_types, rotation=30, ha="right")
plt.legend(title="Accident Severity")


plt.show()

# %% [markdown]
# <h1>Insight No.17 - District with the Fewest Accidents</h1>
# <h3>" Clackmannanshire "</h3>

# %%
accident["District Area"].value_counts().idxmin()

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, " District with the fewest number of casualties :Clackmannanshire", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Insight No.18 - Average Number of Casualties in Urban vs. Rural Areas</h1>

# %%
urban_casualties = accident[accident["Urban_or_Rural_Area"] == "Urban"]["Number_of_Casualties"].mean()
rural_casualties = accident[accident["Urban_or_Rural_Area"] == "Rural"]["Number_of_Casualties"].mean()

# %%
urban_casualties

# %%
rural_casualties

# %%
categories = ["Urban", "Rural"]
average_casualties = [1.2878, 1.4792]  
colors = ["blue", "green"]  
plt.figure(figsize=(6, 5))
plt.bar(categories, average_casualties, color=colors)


plt.xlabel("Area Type")
plt.ylabel("Average Number of Casualties")
plt.title("Average Number of Casualties: Urban vs. Rural Areas")


for i, v in enumerate(average_casualties):
    plt.text(i, v + 0.02, str(round(v, 2)), ha="center", fontsize=12, fontweight="bold")


plt.show()

# %% [markdown]
# <h1>Insight No.19 - Highest Number of Vehicles in a Single Accident</h1>

# %%
max_vehicles = accident["Number_of_Vehicles"].max()
max_vehicles

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, "Highest Number of Vehicles in a Single Accident :32", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Insight No.20 -  Accidents with More Than 5 Casualties</h1>

# %%
high_casualty_accidents = (accident["Number_of_Casualties"] > 5).sum()
high_casualty_accidents

# %%
plt.figure(figsize=(5, 3))
plt.text(0.5, 0.5, " Accidents with more than 5 casualties :2612", fontsize=18, ha='center', va='center', color='#ff6666', weight='bold')
plt.axis("off")  
plt.show()

# %% [markdown]
# <h1>Area Analysis</h1>

# %%
area_year = accident.groupby(['District Area','Year']).size().reset_index(name="Accident Count")
pt = area_year.pivot(index='Year',columns='District Area', values='Accident Count')
pt

# %%
count = 0
for x in pt:
    count += 1
    plt.plot(pt.index,pt[x], label = x , marker ='o')
    if count == 10:
        break

plt.gcf().set_size_inches(13,8)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 count = 0
# ----> 2 for x in pt:
#       3     count += 1
#       4     plt.plot(pt.index,pt[x], label = x , marker ='o')
#
# NameError: name 'pt' is not defined

# %%
type_vh = accident.groupby(['Roadtype','Vehicle_Type']).size().unstack()
sns.heatmap(type_vh , cmap="crest")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 type_vh = accident.groupby(['Roadtype','Vehicle_Type']).size().unstack()
#       2 sns.heatmap(type_vh , cmap="crest")
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...
